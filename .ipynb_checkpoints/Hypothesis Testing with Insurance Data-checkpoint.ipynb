# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# What question am I attempting to answer?
#
# What metric/value do I want to measure to answer this question?
#
# Do I expect the groups to be different in a specific way? (i.e. one group greater than the other).
#
# Or do I just think they'll be different, but don't know how?

# %% [markdown]
# We have been asked to use our hypothesis testing skills to answer the following questions:
#
# - Q1. Do smokers have higher insurance charges than non-smokers?
# Hypothesis, Yes
#
# - Q2. Are men more likely to smoke than women?
# Hypothesis, Yes
#
# - Q3. Do different regions have different charges, on average? Hypothesis, Yes

# %%
df = pd.read_csv('Data/insurance - insurance.csv')
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
table = pd.crosstab(df['sex'], df['smoker'])
table
# Out:
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
# Run the Test and Save the Output
result = stats.chi2_contingency(table)
chi2, p, deg_free, expected_vals = result #this labels the results

# %%
# What was our p-value?
print(p)
p<.05
# Out:
# 0.006548143503580696
# True

# %%
table2 = pd.crosstab(df['charges'], df['smoker'])
table2
# Out:
# smoker       no  yes
# charges
# 1121.87390    1    0
# 1131.50660    1    0
# 1135.94070    1    0
# 1136.39940    1    0
# 1137.01100    1    0
# ...          ..  ...
# 55135.40209   0    1
# 58571.07448   0    1
# 60021.39897   0    1
# 62592.87309   0    1
# 63770.42801   0    1
#
# [1337 rows x 2 columns]

# %%
# Run the Test and Save the Output
result = stats.chi2_contingency(table2)
chi2, p, deg_free, expected_vals = result

# %%
# What was our p-value?
print(p)
p<.05
# Out:
# 0.47943654572545824
# False

# %%
table3 = pd.crosstab(df['charges'], df['region'])
table3
# Out:
# region       northeast  northwest  southeast  southwest
# charges
# 1121.87390           0          0          1          0
# 1131.50660           0          0          1          0
# 1135.94070           0          0          1          0
# 1136.39940           0          0          1          0
# 1137.01100           0          0          1          0
# ...                ...        ...        ...        ...
# 55135.40209          0          1          0          0
# 58571.07448          1          0          0          0
# 60021.39897          0          1          0          0
# 62592.87309          0          0          1          0
# 63770.42801          0          0          1          0
#
# [1337 rows x 4 columns]

# %%
# Run the Test and Save the Output
result = stats.chi2_contingency(table3)
chi2, p, deg_free, expected_vals = result

# %%
# What was our p-value?
print(p)
p<.05
# Out:
# 0.4703353426605913
# False

# %%
sns.displot(data=df, x='charges', col= 'smoker', kde=True)

# %%
sns.displot(data=df, x='charges', col= 'region', kde=True)

# %%
sns.displot(data=df, x='sex', col= 'smoker', kde=True)

# %% [markdown]
# Used Chi-Square due to data being catigorical and not binomial
# I am rejecting to fail the hypothesis for Q1 and 2 as the results and visualizations show
# I am rejecting the 3rd questions's hypothesis due to the above results shown
